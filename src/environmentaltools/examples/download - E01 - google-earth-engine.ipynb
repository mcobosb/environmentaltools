# %% [markdown]
# # download - E01 - google-earth-engine.ipynb
# ##### Revised on: 2025-10-29

# %% [markdown]
# # Configuración de Descarga de Imágenes Sentinel-2
#
# En esta sección se define la configuración para la descarga de series temporales de imágenes Sentinel-2 desde Google Earth Engine. Los parámetros principales incluyen:
#
# - **Área de estudio**: Coordenadas geográficas que delimitan la región de interés
# - **Período temporal**: Desde enero hasta diciembre de 2020
# - **Resolución espacial**: 10 metros por píxel
# - **Filtro de nubes**: Máximo 10% de cobertura nubosa
# - **Directorio de salida**: Las imágenes se guardarán en la carpeta `./satellite_images`
#
# Esta configuración permite obtener imágenes de alta calidad temporal y espacial para análisis de monitoreo ambiental y cambios en el uso del suelo.

# %%
from environmentaltools.download.google_earth_engine import download_sentinel2_timeseries

config = {'project_id': 'my-gee-project',
          'study_area_coords': [[[-6.1, 36.8], [-6.0, 36.8], [-6.0, 36.9], [-6.1, 36.9]]],
          'output_directory': './satellite_images',
          'scale': 10,
          'start_date': '2020-01-01',
          'end_date': '2020-12-31',
          'cloud_percentage': 10.0
}
results = download_sentinel2_timeseries(config)
